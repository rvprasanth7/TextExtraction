# %%
import pandas as pd

# %%
import nltk
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
path = r'C:\Users\RAMKUMAR\Documents\ML\Input\training_data.tsv'
train_data = pd.read_csv(path,delimiter='\t',header=0,error_bad_lines= False,quoting=3)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\RAMKUMAR\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
train_data
# Out:
#                                                    sent  \
# 0                                        Make remainder
# 1             Set a reminder on date 23rd November'2016
# 2                           I need a daily wake up call
# 3                            remind me 6 pm today eveng
# 4                    Hi Pls to make one reminder for me
# 5                 Remind me at 28 December for recharge
# 6                         Can u help me with reminder..
# 7                   Can u pls remind me at 7pm on 8 Jan
# 8                             What is my next reminder?
# 9               Can u please set me an alarm at 7.30 am
# 10    Set a reminder on 4 th Dec of going to meet so...
# 11    Remind me to purchase shoe polish liquid Date:...
# 12    Thanks at least I'll remember my loves birthda...
# 13            I setd a reminder but it dint remained me
# 14    Susan dmello meeting with sujit sir remind him...
# 15    I need to set reminder to msg babbu at 7 in ev...
# ...

# %%
#train_data.head()

# %%
train_data_sent=train_data['sent']

# %%
train_data_sent
# Out:
# 0                                          Make remainder
# 1               Set a reminder on date 23rd November'2016
# 2                             I need a daily wake up call
# 3                              remind me 6 pm today eveng
# 4                      Hi Pls to make one reminder for me
# 5                   Remind me at 28 December for recharge
# 6                           Can u help me with reminder..
# 7                     Can u pls remind me at 7pm on 8 Jan
# 8                               What is my next reminder?
# 9                 Can u please set me an alarm at 7.30 am
# 10      Set a reminder on 4 th Dec of going to meet so...
# 11      Remind me to purchase shoe polish liquid Date:...
# 12      Thanks at least I'll remember my loves birthda...
# 13              I setd a reminder but it dint remained me
# 14      Susan dmello meeting with sujit sir remind him...
# 15      I need to set reminder to msg babbu at 7 in ev...
# ...

# %%
df = train_data_sent.values.tolist()
#df

# %%
for i in df:
    #print(i)
    tokens.append(word_tokenize(str(i)))

# %%
#tokens
ds= train_data.fillna(' ')

# %%
#tokens

# %%
tokens
# Out:
# ['PLS',
#  'Adv',
#  'Chetan',
#  ['Make', 'remainder'],
#  ['Set', 'a', 'reminder', 'on', 'date', '23rd', "November'2016"],
#  ['I', 'need', 'a', 'daily', 'wake', 'up', 'call'],
#  ['remind', 'me', '6', 'pm', 'today', 'eveng'],
#  ['Hi', 'Pls', 'to', 'make', 'one', 'reminder', 'for', 'me'],
#  ['Remind', 'me', 'at', '28', 'December', 'for', 'recharge'],
#  ['Can', 'u', 'help', 'me', 'with', 'reminder..'],
#  ['Can', 'u', 'pls', 'remind', 'me', 'at', '7pm', 'on', '8', 'Jan'],
#  ['What', 'is', 'my', 'next', 'reminder', '?'],
#  ['Can', 'u', 'please', 'set', 'me', 'an', 'alarm', 'at', '7.30', 'am'],
#  ['Set',
#   'a',
#   'reminder',
#   'on',
#   '4',
#   'th',
#   'Dec',
#   'of',
#   'going',
#   'to',
#   'meet',
#   'sonal',
#   'miss',
#   'at',
#   '2:00',
#   'pm'],
#  ['Remind',
#   'me',
#   'to',
#   'purchase',
#   'shoe',
#   'polish',
#   'liquid',
#   'Date:3',
#   'Jan',
#   'Time:6.30',
#   'pm'],
#  ['Thanks',
#   'at',
#   'least',
#   'I',
#   "'ll",
# ...

# %%
#from sklearn.feature_extraction.text import CountVectorizer
#import re
#path1=r'C:\Users\RAMKUMAR\Documents\ML\Input\stopwords.txt'
#def get_stop_words(stop_file_path):
    #"""load stop words"""
    
 #   with open(stop_file_path,'r', encoding='utf-8') as f:
        #stopwords = f.readlines()
        #stop_set = set(m.strip() for m in stopwords)
        #return set(stop_set)
    
#stopwords=get_stop_words(path1)
#sto = list(stopwords)
#print(type(stopwords))

#docx= ds['sent'].tolist()

# %%
#results = [w for w in tokens if not w in sto]
from nltk.corpus import stopwords
stop_words = set(stopwords.words())
sto = list(stop_words)
tokens1 = [w for w in tokens if not w in sto]
#tokens1

# %%
t = []
k=[]


for i in range(len(tokens)):
    for j in range(len(tokens[i])):
        t.append(tokens[i][j])
        
        if(tokens[i][j] in sto):
            t.remove(tokens[i][j])  
    k.append([i,t])
    t=[]

# %%
k
# Out:
# [[0, ['P', 'L', 'S']],
#  [1, ['A']],
#  [2, ['C', 'h']],
#  [3, ['Make', 'remainder']],
#  [4, ['Set', 'reminder', 'date', '23rd', "November'2016"]],
#  [5, ['I', 'need', 'daily', 'wake', 'call']],
#  [6, ['remind', '6', 'pm', 'today', 'eveng']],
#  [7, ['Hi', 'Pls', 'make', 'one', 'reminder']],
#  [8, ['Remind', '28', 'December', 'recharge']],
#  [9, ['Can', 'help', 'reminder..']],
#  [10, ['Can', 'pls', 'remind', '7pm', '8', 'Jan']],
#  [11, ['What', 'next', 'reminder', '?']],
#  [12, ['Can', 'please', 'set', 'alarm', '7.30']],
#  [13,
#   ['Set',
#    'reminder',
#    '4',
#    'th',
#    'Dec',
#    'going',
#    'meet',
#    'sonal',
#    'miss',
#    '2:00',
#    'pm']],
#  [14,
#   ['Remind',
#    'purchase',
#    'shoe',
#    'polish',
#    'liquid',
#    'Date:3',
#    'Jan',
#    'Time:6.30',
#    'pm']],
#  [15,
#   ['Thanks', 'least', 'I', "'ll", 'remember', 'loves', 'birthday', 'time']],
#  [16, ['I', 'setd', 'reminder', 'dint', 'remained']],
# ...

# %%
#tokens

# %%
pathx= r'C:\Users\RAMKUMAR\Documents\ML\Input\eval_data1.txt'
test_xy= pd.read_csv(pathx,delimiter='\t',error_bad_lines=False,quoting=3)
test_xy
# Out:
#                                                   sent
# 0    Reminder for daily reporting and attendance on...
# 1                   How will you remind me let me know
# 2                              Can u remind me till 11
# 3                               Call at 9 am every day
# 4    Remind me to bid for flights on 13th december ...
# 5            Reminder 11am tomorrorw buy bell for papu
# 6         Remind me to book b tickets tonight by 10 pm
# 7                      Can you remind me to masturbate
# 8                      Reminder on invoice preparation
# 9     1 alarm at 1 30am please. Ignore the 12 20am one
# 10   One more reminder....2:00 pm ...today for meeting
# 11                                 call sagar @5:30 pm
# 12                    I'm upset vth d reminder service
# 13                    Remind me to see. Concert at 7pm
# 14                  Remind me again after half an hour
# 15        Need a reminder for payment and phone at 2pm
# ...

# %%
X_train = k

# %%
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()

y_train= train_data['label']
train_vectors = vectorizer.fit_transform(ds)
test_vectors = vectorizer.transform(test_xy)
print(train_vectors.shape, test_vectors.shape)
# Out:
# (2, 2) (1, 2)

# %%
#y_train

# %%
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB().fit(train_vectors, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-243-21e0bf96b334> in <module>
#       1 from sklearn.naive_bayes import MultinomialNB
# ----> 2 clf = MultinomialNB().fit(train_vectors, y_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\naive_bayes.py in fit(self, X, y, sample_weight)
#     583         self : object
#     584         """
# --> 585         X, y = check_X_y(X, y, 'csr')
#     586         _, n_features = X.shape
#     587
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     764         y = y.astype(np.float64)
#     765
# --> 766     check_consistent_length(X, y)
#     767
#     768     return X, y
#
# ...
